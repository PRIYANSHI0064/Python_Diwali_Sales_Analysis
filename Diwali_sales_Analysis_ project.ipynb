# %% [markdown]
# ### Object - Import customer experience by analysing Sales data and increase revenue

# %%
# Import python libraries 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:\python GrowDataSkills\Diwali Sales Data.csv" , encoding = 'Unicode_escape')

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F   28               0
# 1      1000732       Kartik  P00110942      F   35               1
# 2      1001990        Bindu  P00118542      F   35               1
# 3      1001425       Sudevi  P00237842      M   16               0
# 4      1000588         Joni  P00057942      M   28               1
# ...        ...          ...        ...    ...  ...             ...
# 11246  1000695      Manning  P00296942      M   19               1
# 11247  1004089  Reichenbach  P00171342      M   33               0
# 11248  1001209        Oshin  P00201342      F   40               0
# 11249  1004023       Noonan  P00059442      M   37               0
# 11250  1002744      Brumley  P00281742      F   19               0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
df.shape
# Out:
# (11251, 14)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender  Age  Marital_Status           State  \
# 0  1002903  Sanskriti  P00125942      F   28               0     Maharashtra
# 1  1000732     Kartik  P00110942      F   35               1  Andhra Pradesh
# 2  1001990      Bindu  P00118542      F   35               1   Uttar Pradesh
# 3  1001425     Sudevi  P00237842      M   16               0       Karnataka
# 4  1000588       Joni  P00057942      M   28               1         Gujarat
#
#        Zone       Occupation Product_Category  Orders   Amount  Status  \
# 0   Western       Healthcare             Auto       1  23952.0     NaN
# 1  Southern             Govt             Auto       3  23934.0     NaN
# 2   Central       Automobile             Auto       3  23924.0     NaN
# 3  Southern     Construction             Auto       2  23912.0     NaN
# 4   Western  Food Processing             Auto       2  23877.0     NaN
#
#    Unnamed
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
#To find null value in df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age               11251 non-null  int64
#  5   Marital_Status    11251 non-null  int64
#  6   State             11251 non-null  object
#  7   Zone              11251 non-null  object
#  8   Occupation        11251 non-null  object
#  9   Product_Category  11251 non-null  object
#  10  Orders            11251 non-null  int64
#  11  Amount            11239 non-null  float64
#  12  Status            0 non-null      float64
#  13  Unnamed           0 non-null      float64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 1.2+ MB

# %%
# Drop unrelated / Blank columns

df.drop(['Status','Unnamed'], axis =1 , inplace = True)
df
# Out:
#        User_ID    Cust_name Product_ID Gender  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F   28               0
# 1      1000732       Kartik  P00110942      F   35               1
# 2      1001990        Bindu  P00118542      F   35               1
# 3      1001425       Sudevi  P00237842      M   16               0
# 4      1000588         Joni  P00057942      M   28               1
# ...        ...          ...        ...    ...  ...             ...
# 11246  1000695      Manning  P00296942      M   19               1
# 11247  1004089  Reichenbach  P00171342      M   33               0
# 11248  1001209        Oshin  P00201342      F   40               0
# 11249  1004023       Noonan  P00059442      M   37               0
# 11250  1002744      Brumley  P00281742      F   19               0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age               11251 non-null  int64
#  5   Marital_Status    11251 non-null  int64
#  6   State             11251 non-null  object
#  7   Zone              11251 non-null  object
#  8   Occupation        11251 non-null  object
#  9   Product_Category  11251 non-null  object
#  10  Orders            11251 non-null  int64
#  11  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 1.0+ MB

# %%
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
# Filter rows with atleast one null values

# %%
Row_with_nulls = df[df.isnull().any(axis = 1)]
print("row with null values: ")
print(Row_with_nulls)
# Out:
# row with null values:
#      User_ID Cust_name Product_ID Gender  Age  Marital_Status           State  \
# 7    1002092  Shivangi  P00273442      F   61               0     Maharashtra
# 14   1003858      Cano  P00293742      M   46               1  Madhya Pradesh
# 16   1005447       Amy  P00275642      F   48               1  Andhra Pradesh
# 109  1005265    Sakshi  P00296242      F   48               1           Delhi
# 111  1005261   Apoorva  P00057942      F   41               1           Delhi
# 184  1005538    Kartik  P00269542      F   49               1       Karnataka
# 293  1000326  Jonathan  P00120542      M   53               0         Gujarat
# 344  1002507   Lakshmi  P00045842      F   35               1         Gujarat
# 345  1004498   Srishti  P00030842      F   55               0           Delhi
# 452  1004601    Gaurav  P00014442      F   40               1  Madhya Pradesh
# 464  1004528    Anurag  P00338442      F   33               1   Uttar Pradesh
# ...

# %%
# Calculate mean for each category and fill NA with mean for that category

# %%
df["Amount"] = df.groupby(["Product_Category"])["Amount"].transform(lambda x : x.fillna(x.mean()))

# %%
# Selected_rows

selected_rows = df[(df['User_ID']== 1004528) & (df['Product_ID']=='P00338442')]
print(selected_rows)
# Out:
#      User_ID Cust_name Product_ID Gender  Age  Marital_Status          State  \
# 464  1004528    Anurag  P00338442      F   33               1  Uttar Pradesh
#
#         Zone  Occupation Product_Category  Orders        Amount
# 464  Central  Automobile             Food       2  13628.065663

# %%
df['Amount'] = df['Amount'].astype(int)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age', 'Marital_Status',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount'],
#       dtype='object')

# %%
for x in df.index:
    if df.loc[x,'Marital_Status'] == 0 :
       df.loc[x,'Marital_Status'] = 'Married'
    else:
       df.loc[x,'Marital_Status'] = 'Unmarried'

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender  Age Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F   28        Married
# 1      1000732       Kartik  P00110942      F   35      Unmarried
# 2      1001990        Bindu  P00118542      F   35      Unmarried
# 3      1001425       Sudevi  P00237842      M   16        Married
# 4      1000588         Joni  P00057942      M   28      Unmarried
# ...        ...          ...        ...    ...  ...            ...
# 11246  1000695      Manning  P00296942      M   19      Unmarried
# 11247  1004089  Reichenbach  P00171342      M   33        Married
# 11248  1001209        Oshin  P00201342      F   40        Married
# 11249  1004023       Noonan  P00059442      M   37        Married
# 11250  1002744      Brumley  P00281742      F   19        Married
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
df[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11251.000000  11251.000000  11251.000000
# mean      35.421207      2.489290   9460.454626
# std       12.754122      1.115047   5224.434220
# min       12.000000      1.000000    188.000000
# 25%       27.000000      1.500000   5443.500000
# 50%       33.000000      2.000000   8110.000000
# 75%       43.000000      3.000000  12691.500000
# max       92.000000      4.000000  23952.000000

# %%
# Defining fuction to categorieze_age

def categorize_age(Age):
    if Age <= 17:
      return "0-17"
    elif Age <=25:
        return "18-25"
    elif Age <= 35:
        return "26-35"
    elif Age <= 45:
        return "36-45"
    elif Age <= 50:
        return "46-50"
    elif Age <= 55:
        return "51-55"
    else:
        return "55+"

# %%
# Apply function to create a new column "Age_group"

df["Age_group"] = df["Age"].apply(categorize_age)
df
# Out:
#        User_ID    Cust_name Product_ID Gender  Age Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F   28        Married
# 1      1000732       Kartik  P00110942      F   35      Unmarried
# 2      1001990        Bindu  P00118542      F   35      Unmarried
# 3      1001425       Sudevi  P00237842      M   16        Married
# 4      1000588         Joni  P00057942      M   28      Unmarried
# ...        ...          ...        ...    ...  ...            ...
# 11246  1000695      Manning  P00296942      M   19      Unmarried
# 11247  1004089  Reichenbach  P00171342      M   33        Married
# 11248  1001209        Oshin  P00201342      F   40        Married
# 11249  1004023       Noonan  P00059442      M   37        Married
# 11250  1002744      Brumley  P00281742      F   19        Married
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# ...

# %% [markdown]
# #### EDA - Exploratory Data Analysis

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age', 'Marital_Status',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount',
#        'Age_group'],
#       dtype='object')

# %% [markdown]
# * Gender

# %%
# Plotting a bar_chart for gender and it's count 

ax = sns.countplot(x = 'Gender' , data = df)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# plotting a bar_chart for gender v/s total amount

# %%
sales_gen = df.groupby(["Gender"],as_index = False)["Amount"].sum().sort_values(by = "Amount" , ascending = False)

sns.barplot( x = "Gender", y = 'Amount', data = sales_gen)
plt.show()

# %% [markdown]
# **"From above graphs we can see that most of the buyers are Females and even puchasing power of Females are greater than men "**

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age', 'Marital_Status',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount',
#        'Age_group'],
#       dtype='object')

# %% [markdown]
# * Age

# %%
ax = sns.countplot(x = "Age_group" , data = df ,hue = "Gender")

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# plotting a bar_chart for Age_group v/s total amount

# %%
sales_age = df.groupby(["Age_group"],as_index = False)["Amount"].sum().sort_values(by = "Amount" , ascending = False)
sns.barplot(x = "Age_group" , y = "Amount" , data = sales_age)
plt.show()

# %% [markdown]
# **"From above graphs we can see the most of the buyers are from Age_group between '26-35'years  and mostly are Females"**

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age', 'Marital_Status',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount',
#        'Age_group'],
#       dtype='object')

# %% [markdown]
# * State

# %%
# Total Numbers of Orders From top 10 States

Sales_states = df.groupby(["State"], as_index = False)["Orders"].sum().sort_values(by = "Orders",ascending = False).head(10)
sns.set(rc = {'figure.figsize' : (16 ,5)})

ax = sns.barplot(x = "State" , y = "Orders" , data = Sales_states)
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
#  from Top 5 States

Sales_states = df.groupby(["State"], as_index = False)["Orders"].sum().sort_values(by = "Orders",ascending = False).head()
sns.set(rc = {'figure.figsize' : (13,4)})

ax = sns.barplot(x = "State" , y = "Orders" , data = Sales_states)
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
# Total Numbers of Orders From top 10 States

Sales_states = df.groupby(["State"], as_index = False)["Orders"].sum().sort_values(by = "Orders",ascending = False).head(3)
sns.set(rc = {'figure.figsize' : (12 ,3)})

ax = sns.barplot(x = "State" , y = "Orders" , data = Sales_states)
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %% [markdown]
# **"From above graphs we can see that most of the Orders & Total_Sales / Amount are from 'Uttar pradesh' , 'Maharashtra' and 'Karnataka' respectively"**

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age', 'Marital_Status',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount',
#        'Age_group'],
#       dtype='object')

# %% [markdown]
# * Marital_Status

# %%
ax = sns.countplot(x = "Marital_Status", data = df)
sns.set(rc = {'figure.figsize' : (7 , 5)})
for bars in ax.containers:
     ax.bar_label(bars)

# %%
Sales_state = df.groupby(["Marital_Status"], as_index = False)["Amount"].sum().sort_values(by = "Amount" , ascending = False)
sns.set(rc = {"figure.figsize" : (6,5)})
sns.barplot(data = Sales_state , x = "Marital_Status" , y = "Amount")
plt.show()

# %%
Sales_state = df.groupby(["Marital_Status","Gender"], as_index = False)["Amount"].sum().sort_values(by = "Amount" , ascending = False)
sns.set(rc = {"figure.figsize" : (6,5)})
sns.barplot(data = Sales_state , x = "Marital_Status" , y = "Amount", hue = "Gender")
plt.show()

# %% [markdown]
# **From above graphs we can see that most of the buyers are Married (Women) and they have high puchasing power**

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age', 'Marital_Status',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount',
#        'Age_group'],
#       dtype='object')

# %% [markdown]
# * Occupation

# %%
sns.set(rc = {'figure.figsize' : (20, 6)})
ax = sns.countplot(data = df , x = 'Occupation')
for bars in ax.containers:
     ax.bar_label(bars)

# %%
sales_state = df.groupby(["Occupation"],as_index = False)["Amount"].sum().sort_values(by = "Amount" , ascending = False)
sns.set(rc = {"figure.figsize" :(19,6)})
sns.barplot(data = sales_state , x = "Occupation" , y = "Amount")
plt.show()

# %% [markdown]
# **"From above graphs we can see that most of the buyers are working in 'IT','Healthcare' and 'Aviation'Sector"**

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age', 'Marital_Status',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount',
#        'Age_group'],
#       dtype='object')

# %% [markdown]
# * Product_Category

# %%
sns.set(rc = {"figure.figsize" :(24,8)})
ax  = sns.countplot(x = "Product_Category" , data = df)
for bars in ax.containers:
     ax.bar_label(bars)

# %%
sales_state = df.groupby(["Product_Category"] , as_index = False)["Amount"].sum().sort_values(by ="Amount" ,ascending = False).head(10)
sns.set(rc = {"figure.figsize" :(20,5)})
sns.barplot(data =sales_state ,x ="Product_Category" , y = "Amount")
plt.show()

# %% [markdown]
# **" From above graphs we can see that most of the sold products are from 'Food' , 'Clothing' and 'Electromics' Category"**

# %%
# Evaluating number of buyers especially  in Automobile according to the  Gender
Auto_data  = df[df["Product_Category"]=="Auto"]
Auto_data
# Out:
#       User_ID  Cust_name Product_ID Gender  Age Marital_Status  \
# 0     1002903  Sanskriti  P00125942      F   28        Married
# 1     1000732     Kartik  P00110942      F   35      Unmarried
# 2     1001990      Bindu  P00118542      F   35      Unmarried
# 3     1001425     Sudevi  P00237842      M   16        Married
# 4     1000588       Joni  P00057942      M   28      Unmarried
# ...       ...        ...        ...    ...  ...            ...
# 2460  1001941      Gopal  P00259142      M   26      Unmarried
# 2461  1001202    Diwakar  P00277642      F   39        Married
# 4588  1005642     Eplett  P00057542      F   13        Married
# 4651  1004704    Manshul  P00085242      F   24      Unmarried
# 4687  1000157   Michelle  P00102042      F   41      Unmarried
#
#                State      Zone       Occupation Product_Category  Orders  \
# 0        Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
ax = sns.countplot(x = "Gender"  , data = Auto_data)
sns.set(rc = {'figure.figsize' :(16,5)})
for bars in ax.containers:
     ax.bar_label(bars)

# %%
sales_amount = df.groupby(["Gender"],as_index = False),["Amount"]
sns.set(rc = {'figure.figsize' :(10,5)})
ax = sns.barplot( x = "Gender" , y = "Amount" ,data = Auto_data)
for bars in ax.containers:
     ax.bar_label(bars)

# %% [markdown]
# **" From above graphs we can see that most of the buyers are Females but puchasing power are approximatly same for both males and females"**

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age', 'Marital_Status',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount',
#        'Age_group'],
#       dtype='object')

# %% [markdown]
# * Product_ID

# %%
sales_state = df.groupby(["Product_ID"], as_index = False)['Orders'].sum().sort_values(by = "Orders" , ascending = False).head(10)
sns.set(rc = {'figure.figsize':(20,5)})
ax =sns.barplot( x = "Product_ID" , y = "Orders", data = sales_state)
for bars in ax.containers:
     ax.bar_label(bars)
plt.show()

# %%
# Top 10 most  sold products

fig1 , ax1 = plt.subplots(figsize = (12 , 7 ))
df.groupby(["Product_ID"])["Orders"].sum().nlargest(10).sort_values(ascending = False).plot( kind = 'bar')
plt.show()

# %% [markdown]
# **" Married women Age_group 26-35 years from UP , Maharastra and Karnataka Working on IT , Healthcare & Aviation are more likely to buy products from Food , Clothing & Electromics Category"**
